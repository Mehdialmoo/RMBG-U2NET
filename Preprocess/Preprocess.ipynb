# %%
from util import *

img_path = f"images"
msk_path = f"masks"

# %%
# Rename(path=img_path,category="Terrestrial")

# %%
# resize(path="D:\git ex\DA\RMBG-U2NET\Data\images",new_size=(512,512))

# %%
create_csv(img_path, msk_path , "Dataset.csv")

# %%
plot_Data(img_path)
