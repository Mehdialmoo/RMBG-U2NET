# %%
from util import *

img_path = "D:\git ex\DA\RMBG-U2NET\Data\images"
msk_path = "D:\git ex\DA\RMBG-U2NET\Data\masks"

# %%
Rename(path="D:\git ex\DA\RMBG-U2NET\Data\images",category="People")

# %%
resize(path="D:\git ex\DA\RMBG-U2NET\Data\images",new_size=(512,512))

# %%
create_csv(img_path, msk_path , "D:\git ex\DA\RMBG-U2NET\Data\Dataset.csv")

# %%
plot_Data(img_path)
